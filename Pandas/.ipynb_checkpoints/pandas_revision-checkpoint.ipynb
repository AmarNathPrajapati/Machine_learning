# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pandas
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "name":["Chandan","Golu","Amar"],
    "marks":[80,90,95],
    "Age":[20,20,20]
}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#       name  marks  Age
# 0  Chandan     80   20
# 1     Golu     90   20
# 2     Amar     95   20

# %%
df.to_csv('dosto.csv',index = False)

# %%
df.head(2)
# Out:
#       name  marks  Age
# 0  Chandan     80   20
# 1     Golu     90   20

# %%
df.tail(2)
# Out:
#    name  marks  Age
# 1  Golu     90   20
# 2  Amar     95   20

# %%
df.describe()
# Out:
#            marks   Age
# count   3.000000   3.0
# mean   88.333333  20.0
# std     7.637626   0.0
# min    80.000000  20.0
# 25%    85.000000  20.0
# 50%    90.000000  20.0
# 75%    92.500000  20.0
# max    95.000000  20.0

# %%
mycsv = pd.read_csv('friends.csv')

# %%
mycsv
# Out:
#        name  marks  Age
# 0   Chandan     80   20
# 1      Golu     90   20
# 2      Amar     95   20
# 3    Pramod     90   22
# 4   Saurabh     92   21
# 5    Shivam     88   22
# 6  Himanshu     85   22
# 7   Aadarsh     82   21

# %%
mycsv['name']
# Out:
# 0     Chandan
# 1        Golu
# 2        Amar
# 3      Pramod
# 4     Saurabh
# 5      Shivam
# 6    Himanshu
# 7     Aadarsh
# Name: name, dtype: object

# %%
mycsv['Age']
# Out:
# 0    20
# 1    20
# 2    20
# 3    22
# 4    21
# 5    22
# 6    22
# 7    21
# Name: Age, dtype: int64

# %%
mycsv['name'][0]
# Out:
# 'Chandan'

# %%
mycsv['Age'][1]=21
# Out:
# C:\Users\amarn\AppData\Local\Temp\ipykernel_20476\2199929463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mycsv['Age'][1]=21

# %%
mycsv
# Out:
#        name  marks  Age
# 0   Chandan     80   20
# 1      Golu     90   21
# 2      Amar     95   20
# 3    Pramod     90   22
# 4   Saurabh     92   21
# 5    Shivam     88   22
# 6  Himanshu     85   22
# 7   Aadarsh     82   21

# %%
mycsv.to_csv('mycsv.csv')

# %%
mycsv.index=['first','second','third','fourth','fifth','sixth','seventh','eigthth']

# %%
mycsv
# Out:
#              name  marks  Age
# first     Chandan     80   20
# second       Golu     90   21
# third        Amar     95   20
# fourth     Pramod     90   22
# fifth     Saurabh     92   21
# sixth      Shivam     88   22
# seventh  Himanshu     85   22
# eigthth   Aadarsh     82   21

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.106612
# 1     0.646820
# 2     0.259422
# 3     0.127615
# 4     0.280220
# 5     0.334878
# 6     0.639572
# 7     0.250109
# 8     0.223654
# 9     0.099733
# 10    0.083885
# 11    0.437317
# 12    0.370218
# 13    0.227093
# 14    0.810853
# 15    0.297107
# 16    0.773329
# 17    0.821091
# 18    0.503375
# 19    0.080366
# 20    0.464086
# 21    0.279546
# 22    0.279180
# 23    0.991985
# 24    0.730486
# 25    0.124077
# 26    0.386179
# 27    0.540648
# 28    0.157157
# 29    0.222157
# 30    0.662737
# 31    0.638860
# 32    0.454310
# 33    0.537831
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newDf = pd.DataFrame(np.random.rand(334,5))

# %%
newDf
# Out:
#             0         1         2         3         4
# 0    0.284653  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331  0.698100  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0  0
#
# [334 rows x 5 columns]

# %%
newDf[0]
# Out:
# 0          amar
# 1      0.525809
# 2      0.421701
# 3      0.103765
# 4      0.526644
#          ...
# 329    0.147668
# 330    0.255487
# 331      0.6981
# 332    0.152142
# 333    0.561729
# Name: 0, Length: 334, dtype: object

# %% [markdown]
# # View and Copy of dataframe

# %%
df2 = newDf

# %%
df2
# Out:
#             0         1         2         3         4
# 0        amar  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331    0.6981  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %%
df2[0][0]= 12345

# %%
df2
# Out:
#             0         1         2         3         4
# 0       12345  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331    0.6981  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %%
newDf
# Out:
#             0         1         2         3         4
# 0       12345  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331    0.6981  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %% [markdown]
# # for actual copy

# %%
newDf2 = newDf.copy()

# %%
newDf2
# Out:
#             0         1         2         3         4
# 0       12345  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331    0.6981  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %%
newDf2[0][0] = 'amar'
# Out:
# C:\Users\amarn\AppData\Local\Temp\ipykernel_20476\2943713679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf2[0][0] = 'amar'

# %%
newDf2
# Out:
#             0         1         2         3         4
# 0        amar  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331    0.6981  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %%
newDf
# Out:
#             0         1         2         3         4
# 0       12345  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331    0.6981  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %% [markdown]
# # To prevent from error using the concept of the loc

# %%
newDf.loc[0,0] = 654

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0       654  0.108627  0.848361  0.636169  0.345678
# 1  0.525809  0.395310  0.337885  0.883111  0.887370

# %%
newDf.columns = list('ABCDE')

# %%
newDf
# Out:
#             A         B         C         D         E
# 0         654  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331    0.6981  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %%
newDf.loc[0,'A']='chandan'

# %%
newDf
# Out:
#             A         B         C         D         E
# 0     chandan  0.108627  0.848361  0.636169  0.345678
# 1    0.525809  0.395310  0.337885  0.883111  0.887370
# 2    0.421701  0.701586  0.110358  0.420730  0.655721
# 3    0.103765  0.473405  0.173802  0.564839  0.762842
# 4    0.526644  0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...       ...
# 329  0.147668  0.003584  0.982641  0.810310  0.719193
# 330  0.255487  0.201482  0.567097  0.043241  0.489604
# 331    0.6981  0.317337  0.587897  0.042820  0.649016
# 332  0.152142  0.338860  0.827590  0.345339  0.135417
# 333  0.561729  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 5 columns]

# %%
newDf.drop('A',axis = 1)
# Out:
#             B         C         D         E
# 0    0.108627  0.848361  0.636169  0.345678
# 1    0.395310  0.337885  0.883111  0.887370
# 2    0.701586  0.110358  0.420730  0.655721
# 3    0.473405  0.173802  0.564839  0.762842
# 4    0.625194  0.346550  0.176708  0.819281
# ..        ...       ...       ...       ...
# 329  0.003584  0.982641  0.810310  0.719193
# 330  0.201482  0.567097  0.043241  0.489604
# 331  0.317337  0.587897  0.042820  0.649016
# 332  0.338860  0.827590  0.345339  0.135417
# 333  0.095848  0.534617  0.338957  0.715192
#
# [334 rows x 4 columns]

# %%
newDf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.337885  0.883111
# 2  0.110358  0.420730

# %%
newDf.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.848361  0.636169
# 1    0.337885  0.883111
# 2    0.110358  0.420730
# 3    0.173802  0.564839
# 4    0.346550  0.176708
# ..        ...       ...
# 329  0.982641  0.810310
# 330  0.567097  0.043241
# 331  0.587897  0.042820
# 332  0.827590  0.345339
# 333  0.534617  0.338957
#
# [334 rows x 2 columns]

# %%
newDf.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.525809  0.395310  0.337885  0.883111  0.887370
# 2  0.421701  0.701586  0.110358  0.420730  0.655721
